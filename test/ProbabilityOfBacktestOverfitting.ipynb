# %%
using Combinatorics
using Statistics
using Distributions
using LinearAlgebra
using Plots

# %%
include("ProbabilityOfBacktestOverfitting.jl")
# Out:
# ProbabilityOfBacktestOverfitting

# %%
function sharpratio(returns,riskFree)
    return (mean(returns)-riskFree)/std(returns)
end
# Out:
# sharpratio (generic function with 1 method)

# %%
n = Normal(0,0.1)
m = Normal(0,0.1)
data = hcat(rand(m,10000),rand(n,(10000,100)))
pbo,density =ProbabilityOfBacktestOverfitting(data,16,sharpratio);

# %%
histogram(density)
